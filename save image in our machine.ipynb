# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread("dog-image.jpg")
plt.imshow(img)

# %%
# save image
cv2.imwrite("sample-dogy-image.jpg", img)
# Out:
# True

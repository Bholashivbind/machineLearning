# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
img = Image.open("dog-image.jpg")

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img_arr = np.asarray(img)
type(img_arr)
# Out:
# numpy.ndarray

# %%
img_arr.shape
# Out:
# (3161, 4169, 3)

# %%
img_arr
# Out:
# array([[[ 15,  38,  10],
#         [ 15,  38,  10],
#         [ 15,  38,  12],
#         ...,
#         [  8,  18,   7],
#         [  8,  18,   7],
#         [  8,  18,   7]],
#
#        [[ 15,  38,  10],
#         [ 15,  38,  10],
#         [ 15,  38,  12],
#         ...,
#         [  8,  18,   7],
#         [  8,  18,   7],
#         [  8,  18,   7]],
#
#        [[ 15,  38,  10],
#         [ 15,  38,  10],
#         [ 15,  38,  10],
#         ...,
#         [  8,  18,   7],
#         [  8,  18,   7],
#         [  8,  18,   7]],
#
#        ...,
#
#        [[139, 161,  61],
#         [138, 160,  60],
#         [138, 160,  60],
#         ...,
#         [156, 168,  82],
#         [156, 168,  82],
#         [155, 167,  81]],
#
#        [[139, 161,  61],
#         [138, 160,  60],
#         [138, 160,  60],
#         ...,
#         [156, 168,  82],
#         [156, 168,  82],
#         [155, 167,  81]],
#
#        [[139, 161,  61],
#         [140, 162,  62],
#         [140, 162,  64],
#         ...,
#         [156, 168,  82],
#         [156, 168,  82],
#         [156, 168,  82]]], dtype=uint8)

# %%
plt.imshow(img_arr)

# %%
img_arr.shape
# Out:
# (3161, 4169, 3)
